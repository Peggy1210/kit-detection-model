# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/PCRD_model
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/PCRD_model

# %% [markdown]
# # Photo Preprocessing

# %%
# import
import os
import numpy as np
import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import layers
# from tensorflow.keras import models

from cv2 import imread, IMREAD_GRAYSCALE
from pandas import read_csv
# import matplotlib.pyplot as plt

# %%
# Seed
SEED = 1234
tf.random.set_seed(SEED)

# Data Size
N = 158
# Image Size
IMG_SIZE = (200, 504, 1)
# Number of Classess
NUM_CLASSES = 5

# %%
PATH = "training_data"
file_dir = os.listdir(PATH)
file_dir.sort()
X_train = np.array([])

tmp = []

for i in range(len(file_dir)):
    img = imread(PATH + "/" + file_dir[i], IMREAD_GRAYSCALE)
    img = np.expand_dims(img[:], axis = 2)
    tmp.append(img)
    # np.append(X_train, img)

# print(tmp.shape)
X_train = np.array(tmp) / 255

# Prepare y_train
data = read_csv("multi_label.csv")
y_train = data["label"]
y_train = np.expand_dims(y_train[:N], axis = 1)

# %%
# Shuffle
from sklearn.model_selection import train_test_split

val_split = 0.1
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=val_split, stratify=y_train)

# X_train = np.concatenate((X_t, X_v))
# y_train = np.concatenate((y_t, y_v))

# %%
# !pip install keras_preprocessing
# Out:
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Installing collected packages: keras_preprocessing
# Successfully installed keras_preprocessing-1.1.2

# %%
# Data augmentation and splitting data
from keras_preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, zoom_range=0.3, validation_split=0.1)
training = train_datagen.flow(X_train, y_train, batch_size=32, subset='training')
validation = train_datagen.flow(X_train, y_train, batch_size=16, subset='validation')

# %%
from sklearn.model_selection import train_test_split

# Linear model
# X_train_linear, X_val_linear, y_train_linear, y_val_linear = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
training_linearX = np.reshape(training.x, (training.x.shape[0], -1))
validation_linearX = np.reshape(validation.x, (validation.x.shape[0], -1))

model_linear = tf.keras.models.Sequential()
model_linear.add(tf.keras.layers.Dense(1))

model_linear.compile(optimizer='sgd',
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy(),])

history_linear = model_linear.fit(training_linearX, training.y, batch_size=16, epochs=1, validation_data=(validation_linearX, validation.y))
# Out:
# 8/8 [==============================] - 11s 151ms/step - loss: 12.8943 - binary_accuracy: 0.5391 - val_loss: 17.6285 - val_binary_accuracy: 0.4286

# %%
X_test_linear = np.reshape(X_test, (X_test.shape[0], -1))

predict_linear = model_linear.predict(X_test_linear) #; print(predict_linear)

# predict_linear = (predict_linear > 0.5).astype('int32').flatten()
predict_linear = tf.argmax(predict_linear, axis=1)

from sklearn.metrics import f1_score
score_linear = f1_score(y_test, predict_linear, average=None); print(score_linear)

# mse_linear = tf.keras.losses.mean_squared_error(y_test, predict_linear).numpy(); print(mse_linear)
# mae_linear = tf.keras.losses.mean_absolute_error(y_test, predict_linear).numpy(); print(mae_linear)
# Out:
# 1/1 [==============================] - 0s 116ms/step
# [0.72 0.   0.   0.  ]

# %%
# build model
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=IMG_SIZE))
# model.add(tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(tf.keras.layers.Conv2D(64, 2, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(2, strides=2))
model.add(tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
# model.add(Activation('relu'))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(NUM_CLASSES, activation='sigmoid'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(), ])

model.summary()

history = model.fit(training, batch_size=8, epochs=20, validation_data=validation)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 504, 64)      320
#
#  max_pooling2d (MaxPooling2  (None, 100, 252, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 100, 252, 64)      36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 50, 126, 64)       0
#  g2D)
#
#  flatten (Flatten)           (None, 403200)            0
#
#  dense_1 (Dense)             (None, 64)                25804864
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 25842437 (98.58 MB)
# Trainable params: 25842437 (98.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 12s 599ms/step - loss: 1.4932 - sparse_categorical_accuracy: 0.3281 - val_loss: 1.5113 - val_sparse_categorical_accuracy: 0.2143
# Epoch 2/20
# 4/4 [==============================] - 5s 1s/step - loss: 1.2484 - sparse_categorical_accuracy: 0.5156 - val_loss: 1.3075 - val_sparse_categorical_accuracy: 0.4286
# Epoch 3/20
# 4/4 [==============================] - 3s 565ms/step - loss: 1.1985 - sparse_categorical_accuracy: 0.5391 - val_loss: 1.4720 - val_sparse_categorical_accuracy: 0.4286
# Epoch 4/20
# 4/4 [==============================] - 3s 707ms/step - loss: 1.1425 - sparse_categorical_accuracy: 0.5312 - val_loss: 1.4151 - val_sparse_categorical_accuracy: 0.4286
# Epoch 5/20
# 4/4 [==============================] - 3s 789ms/step - loss: 1.1999 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.3401 - val_sparse_categorical_accuracy: 0.4286
# Epoch 6/20
# 4/4 [==============================] - 3s 736ms/step - loss: 1.1658 - sparse_categorical_accuracy: 0.5391 - val_loss: 1.3082 - val_sparse_categorical_accuracy: 0.4286
# Epoch 7/20
# 4/4 [==============================] - 5s 1s/step - loss: 1.1359 - sparse_categorical_accuracy: 0.5312 - val_loss: 1.4968 - val_sparse_categorical_accuracy: 0.2857
# Epoch 8/20
# 4/4 [==============================] - 2s 516ms/step - loss: 1.0766 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.5044 - val_sparse_categorical_accuracy: 0.4286
# Epoch 9/20
# 4/4 [==============================] - 2s 526ms/step - loss: 1.1265 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.2921 - val_sparse_categorical_accuracy: 0.4286
# Epoch 10/20
# 4/4 [==============================] - 2s 479ms/step - loss: 1.0742 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.5531 - val_sparse_categorical_accuracy: 0.3571
# Epoch 11/20
# 4/4 [==============================] - 1s 283ms/step - loss: 1.0616 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.4156 - val_sparse_categorical_accuracy: 0.3571
# Epoch 12/20
# 4/4 [==============================] - 1s 300ms/step - loss: 1.0881 - sparse_categorical_accuracy: 0.5703 - val_loss: 1.3413 - val_sparse_categorical_accuracy: 0.3571
# Epoch 13/20
# 4/4 [==============================] - 2s 491ms/step - loss: 1.1271 - sparse_categorical_accuracy: 0.4297 - val_loss: 1.3230 - val_sparse_categorical_accuracy: 0.3571
# Epoch 14/20
# 4/4 [==============================] - 2s 370ms/step - loss: 1.1148 - sparse_categorical_accuracy: 0.5312 - val_loss: 1.3446 - val_sparse_categorical_accuracy: 0.4286
# Epoch 15/20
# 4/4 [==============================] - 1s 273ms/step - loss: 1.0485 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.6802 - val_sparse_categorical_accuracy: 0.4286
# Epoch 16/20
# 4/4 [==============================] - 1s 281ms/step - loss: 1.0421 - sparse_categorical_accuracy: 0.5859 - val_loss: 1.6728 - val_sparse_categorical_accuracy: 0.3571
# Epoch 17/20
# 4/4 [==============================] - 1s 276ms/step - loss: 1.0322 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.5187 - val_sparse_categorical_accuracy: 0.3571
# Epoch 18/20
# 4/4 [==============================] - 1s 283ms/step - loss: 0.9854 - sparse_categorical_accuracy: 0.5625 - val_loss: 1.3461 - val_sparse_categorical_accuracy: 0.5000
# Epoch 19/20
# 4/4 [==============================] - 1s 296ms/step - loss: 1.0098 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.5791 - val_sparse_categorical_accuracy: 0.3571
# Epoch 20/20
# 4/4 [==============================] - 1s 281ms/step - loss: 0.9409 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.1622 - val_sparse_categorical_accuracy: 0.5000

# %%
import matplotlib.pyplot as plt

# plot loss curve
plt.figure(1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# plot accuracy curve
plt.figure(2)
plt.plot(history.history['sparse_categorical_accuracy'], label='accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

train_loss = model.evaluate(training)
val_loss = model.evaluate(validation)
# Out:
# 4/4 [==============================] - 1s 201ms/step - loss: 1.0439 - sparse_categorical_accuracy: 0.5547
# 1/1 [==============================] - 0s 128ms/step - loss: 1.3941 - sparse_categorical_accuracy: 0.4286

# %%
predict = model.predict(X_test)
predict = tf.argmax(predict, axis=1)

from sklearn.metrics import f1_score
score = f1_score(y_test, predict, average=None); print(score)
# mse = tf.keras.losses.mean_squared_error(y_test, predict).numpy(); print(mse)
# mae = tf.keras.losses.mean_absolute_error(y_test, predict).numpy(); print(mae)
# Out:
# 1/1 [==============================] - 1s 599ms/step
# [0.66666667 0.         0.         0.        ]

# %% [markdown]
# # Save Model

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('single_model.tflite', 'wb') as f:
  f.write(tflite_model)
